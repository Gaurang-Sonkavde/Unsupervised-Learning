# %% [markdown]
# # Name - Gaurang Vivek Sonkavde
#
# # Class - M.Tech AI-ML
#
# # PRN Number - 21070149023¶
#
# # Subject - Unsupervised Learning

# %% [markdown]
# ##  10)  Implement the Birch Algorithm and create dataset with blob

# %% [markdown]
# ### Birch Algorithm
#
# Balanced Iterative Reducing and Clustering using Hierarchies (BIRCH) is a clustering algorithm that can cluster large datasets by first generating a small and compact summary of the the large dataset that retains as much information as possible. This smaller summary is then clustered instead of clustering the larger dataset.

# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
sns.set()
from sklearn.datasets import make_blobs
from sklearn.cluster import Birch

# %% [markdown]
# ### Make Blobs

# %%
X, clusters = make_blobs(n_samples=1000, centers=12, cluster_std=0.50, random_state=0)
plt.scatter(X[:,0], X[:,1], alpha=0.7, edgecolors='b')

# %% [markdown]
# ### Model Building

# %%
model = Birch(branching_factor=50, n_clusters=None, threshold=1.5)
model.fit(X)
# Out:
# Birch(n_clusters=None, threshold=1.5)

# %%
predict = model.predict(X)
predict
# Out:
# array([ 7,  0,  1,  2,  3,  4,  5,  6,  6,  7,  2,  8,  9,  1,  6,  5,  0,
#         9,  6,  0,  0,  5,  1,  4,  8,  2,  1,  7,  0,  4, 10,  1,  5,  2,
#         1,  9,  6,  6,  5,  4,  7,  1,  8,  7,  9,  1,  6,  5,  0,  3, 11,
#         5, 10,  6,  2,  7,  0, 11,  2, 11,  5,  4,  9,  1,  9,  6,  8,  8,
#        11,  9, 11,  6,  0,  5,  8,  2,  9,  3,  3,  1, 10,  2,  7,  4,  0,
#         5,  0,  6,  8,  6,  9,  7,  0,  4, 11,  2, 11,  3, 11,  5,  0,  3,
#         4,  2,  3,  5,  5,  1, 11,  6,  7,  5,  1,  0,  9,  1, 11,  7,  8,
#        11,  6,  7,  6,  9,  6,  6,  5,  9,  1,  7,  2,  4,  8,  3,  7,  0,
#         0,  2,  5, 11,  8,  3, 10,  7,  5, 11,  6,  9,  4,  6,  9,  5,  6,
#         5,  1,  3,  5,  9, 10,  5,  7, 10,  0,  9,  1,  2,  6,  0,  5,  0,
#         7,  0,  5,  4,  1,  5,  3,  5,  3,  1,  4, 11,  2,  0,  5,  8,  5,
#         5,  5, 10,  2,  7,  8,  5, 11, 11,  9,  0,  7,  6,  3,  6,  7,  9,
# ...

# %%
plt.scatter(X[:,0], X[:,1], c=predict, cmap='rainbow', alpha=0.7, edgecolors='b')

# %%
data = np.array([[2,6],[4,5],[4,7],[6,2],[7,2],[8,4],[7,9]])
data
# Out:
# array([[2, 6],
#        [4, 5],
#        [4, 7],
#        [6, 2],
#        [7, 2],
#        [8, 4],
#        [7, 9]])

# %%
plt.scatter(data[:,0], data[:,1], alpha=0.7, edgecolors='b')

# %%
model = Birch(branching_factor=2, n_clusters=None, threshold=1.5)
model.fit(data)
# Out:
# Birch(branching_factor=2, n_clusters=None, threshold=1.5)

# %%
pred = model.predict(data)
pred
# Out:
# array([1, 1, 1, 0, 0, 0, 2])

# %%
plt.scatter(data[:,0], data[:,1], c=pred, cmap='rainbow', alpha=0.7, edgecolors='b')
