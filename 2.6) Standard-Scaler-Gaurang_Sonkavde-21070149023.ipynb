# %% [markdown]
# # Name - Gaurang Vivek Sonkavde
#
# # Class - M.Tech AI-ML
#
# # PRN Number - 21070149023¶
#
# # Subject - Unsupervised Learning

# %% [markdown]
# # 2.6) Standard Scalling

# %% [markdown]
# ### Import Libraries and Load

# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv(r"C:\Users\gaura\OneDrive\Desktop\DataSets\diabetes.csv")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# ### Standard Scalling

# %%
X = df['Glucose']

# %%
sc = StandardScaler()

# %%
sc.fit_transform(df[["Glucose"]])
# Out:
# array([[ 8.48323795e-01],
#        [-1.12339636e+00],
#        [ 1.94372388e+00],
#        [-9.98207780e-01],
#        [ 5.04055196e-01],
#        [-1.53184856e-01],
#        [-1.34247638e+00],
#        [-1.84482001e-01],
#        [ 2.38188392e+00],
#        [ 1.28489452e-01],
#        [-3.40967728e-01],
#        [ 1.47426670e+00],
#        [ 5.66649487e-01],
#        [ 2.13150675e+00],
#        [ 1.41167241e+00],
#        [-6.53939181e-01],
#        [-9.05905652e-02],
#        [-4.34859164e-01],
#        [-5.60047745e-01],
#        [-1.84482001e-01],
#        [ 1.59786597e-01],
#        [-6.85236326e-01],
#        [ 2.35058677e+00],
#        [-5.92934199e-02],
#        [ 6.91838068e-01],
#        [ 1.28489452e-01],
#        [ 8.17026649e-01],
#        [-7.47830617e-01],
#        [ 7.54432359e-01],
#        [-1.21887711e-01],
#        [-3.72264873e-01],
#        [ 1.16129525e+00],
#        [-1.02950492e+00],
#        [-9.04316344e-01],
#        [ 3.45980161e-02],
# ...

# %% [markdown]
# # Standard Scalling Done
